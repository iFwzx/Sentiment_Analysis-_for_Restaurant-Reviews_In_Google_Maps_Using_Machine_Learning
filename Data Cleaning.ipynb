# %%
import pandas as pd

df = pd.read_csv('Merged Data.csv')

# %%
df.shape
# Out:
# (31538, 4)

# %%
df.head()
# Out:
#                name       rating     review  \
# 0  dalal Alsharqawi  an hour ago   5 stars
# 1        noor jbara  2 hours ago   5 stars
# 2      محمد الشعيلي  4 hours ago   5 stars
# 3        SMILE DAYS  7 hours ago   5 stars
# 4               M H  8 hours ago   5 stars
#
#                                             duration
# 0  (Translated by Google) A beautiful restaurant ...
# 1            A little overpriced but delicious pizza
# 2  (Translated by Google) Very beautiful 🤩 deserv...
# 3  (Translated by Google) There is a response to ...
# 4  (Translated by Google) The best pizza in the w...

# %%
df.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=['duration'],
    inplace=True
)

# %%
df.head()
# Out:
#                name       rating     review  \
# 0  dalal Alsharqawi  an hour ago   5 stars
# 1        noor jbara  2 hours ago   5 stars
# 2      محمد الشعيلي  4 hours ago   5 stars
# 3        SMILE DAYS  7 hours ago   5 stars
# 4               M H  8 hours ago   5 stars
#
#                                             duration
# 0  (Translated by Google) A beautiful restaurant ...
# 1            A little overpriced but delicious pizza
# 2  (Translated by Google) Very beautiful 🤩 deserv...
# 3  (Translated by Google) There is a response to ...
# 4  (Translated by Google) The best pizza in the w...

# %%
df.rename(columns={"rating": "duration", "review": "rating", "duration": "review"}, inplace=True)

# %%
df['rating'].value_counts()
# Out:
#  5 stars     12856
#  4 stars      3890
#  1 star       2269
#  3 stars      2098
#  2 stars      1057
# Name: rating, dtype: int64

# %%
import seaborn as sns
# count of each type 
sns.countplot(df['rating'])
# Out:
# E:\Anaconda\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
df['rating'] = df['rating'].str.replace('stars', '')
df['rating'] = df['rating'].str.replace('star', '')

# %%
df.head()
# Out:
#                name     duration rating  \
# 0  dalal Alsharqawi  an hour ago    5
# 1        noor jbara  2 hours ago    5
# 2      محمد الشعيلي  4 hours ago    5
# 3        SMILE DAYS  7 hours ago    5
# 4               M H  8 hours ago    5
#
#                                               review
# 0  (Translated by Google) A beautiful restaurant ...
# 1            A little overpriced but delicious pizza
# 2  (Translated by Google) Very beautiful 🤩 deserv...
# 3  (Translated by Google) There is a response to ...
# 4  (Translated by Google) The best pizza in the w...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22170 entries, 0 to 31535
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      22169 non-null  object
#  1   duration  22170 non-null  object
#  2   rating    22170 non-null  object
#  3   review    22170 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
df['rating'] = df['rating'].astype(str).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22170 entries, 0 to 31535
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      22169 non-null  object
#  1   duration  22170 non-null  object
#  2   rating    22170 non-null  int32
#  3   review    22170 non-null  object
# dtypes: int32(1), object(3)
# memory usage: 1.3+ MB

# %%
sentiment = []
for row in df['rating']:
        if row == 1 :    sentiment.append('Negative')
        elif row == 2:   sentiment.append('Negative')
        elif row == 3:   sentiment.append('Neutral')
        elif row == 4:   sentiment.append('Positive')
        elif row == 5:   sentiment.append('Positive')

# %%
sentiment
# Out:
# ['Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
# ...

# %%
df['sentiment'] = sentiment

# %%
df
# Out:
#                    name     duration  rating  \
# 0      dalal Alsharqawi  an hour ago       5
# 1            noor jbara  2 hours ago       5
# 2          محمد الشعيلي  4 hours ago       5
# 3            SMILE DAYS  7 hours ago       5
# 4                   M H  8 hours ago       5
# ...                 ...          ...     ...
# 31531     Ghandoora Abd   a year ago       3
# 31532             M. AA   a year ago       5
# 31533     محمد ابو فيصل   a year ago       3
# 31534        Sara Ahmad   a year ago       5
# 31535     Discovery Com   a year ago       3
#
#                                                   review sentiment
# 0      (Translated by Google) A beautiful restaurant ...  Positive
# 1                A little overpriced but delicious pizza  Positive
# 2      (Translated by Google) Very beautiful 🤩 deserv...  Positive
# 3      (Translated by Google) There is a response to ...  Positive
# 4      (Translated by Google) The best pizza in the w...  Positive
# ...

# %%
df.to_csv('Data V3.csv',index=False, un)

# %%
df = df[['review', 'sentiment']]

# %%
df.head()
# Out:
#                                               review sentiment
# 0  (Translated by Google) A beautiful restaurant ...  Positive
# 1            A little overpriced but delicious pizza  Positive
# 2  (Translated by Google) Very beautiful 🤩 deserv...  Positive
# 3  (Translated by Google) There is a response to ...  Positive
# 4  (Translated by Google) The best pizza in the w...  Positive

# %%
# counts of missing values in dataset 
df.isna().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
import re

def remove_emojis(text):
  #print(text) # with emoji
  emoji_pattern = re.compile("["
          u"\U0001F600-\U0001F64F"  # emoticons
          u"\U0001F300-\U0001F5FF"  # symbols & pictographs
          u"\U0001F680-\U0001F6FF"  # transport & map symbols
          u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                            "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', text)

# %%
import re
import emoji
import nltk # for processing texts
from nltk.corpus import stopwords # list of stop words
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def clean_text(text):
    # Remove emoji
    text = remove_emojis(text)
    # Remove special characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove multiple spaces
    text = re.sub(r'\s+', ' ', text)
    
    text = ' '.join([word for word in text.split() if word not in stopwords.words("english")]) # remove stop word
    return text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['review'] = df['review'].apply(clean_text)
# Out:
# C:\Users\Aziz\AppData\Local\Temp\ipykernel_26204\3232353329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(clean_text)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  translated google beautiful restaurant beautif...  Positive
# 1                  little overpriced delicious pizza  Positive
# 2  translated google beautiful deserves stars ori...  Positive
# 3  translated google response owner restaurant re...  Positive
# 4   translated google best pizza whole east original  Positive

# %%
# counts of missing values in dataset 
df.isna().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df['review'][4]
# Out:
# 'translated google best pizza whole east original'

# %%
df['review'] = df['review'].str.replace('translated google ', '')
df['review'] = df['review'].str.replace(' original ', '')
# Out:
# C:\Users\Aziz\AppData\Local\Temp\ipykernel_26204\1118507964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].str.replace('translated google ', '')
# C:\Users\Aziz\AppData\Local\Temp\ipykernel_26204\1118507964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].str.replace(' original ', '')

# %%
df['review'][4]
# Out:
# 'best pizza whole east original'

# %%
# counts of missing values in dataset 
df.isna().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.to_csv('Data V2.csv',index=False)

# %%
df = pd.read_csv('Data V2.csv')

# %%
# counts of missing values in dataset 
df.isna().sum()
# Out:
# review       178
# sentiment      0
# dtype: int64
